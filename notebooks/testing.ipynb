# %%
import sys
sys.path.append('../src/')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import json
import scipy
from antenna import Antenna
import itertools

# %%
with open("../config.json", 'r') as cfg:
    params = json.load(cfg)

antenna_params = params["antenna_params"]
opt_params = params["optimisation_params"]

# %%
antenna_params['N'] = 10

# %%
antenna = Antenna(antenna_params)
antenna.set_configuration((1, 0, 0, 1, 0, 1, 0, 0, 0, 0))
antenna.set_objective(weights=[1.0, 1.0])
antenna.set_jacobian(weights=[1.0, 1.0])
antenna.set_hessian(weights=[1.0, 1.0])

# %%
probe = np.random.rand() * np.ones(antenna.N)
# print(f"Probe signal: \n{probe}\n")
# print(f"Objective_f: \n{antenna.objective(probe)}\n")
# print(f"Objective_grad_f: \n{antenna.jac(probe)}\n")
# print(f"Objective_hess_f: \n{antenna.hess(probe)}\n")

# %%
antenna.get_optimal_current_allocation(opt_params, x0=probe, jac=False, hess=False, cons=False)
# Out:
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------|
# |   1   |  21   |   0   | +4.0848e+05 | 1.00e+00 | 2.48e+05 | 0.00e+00 | 1.00e+00 |   0   |
# |   2   |  42   |   1   | +9.7744e+04 | 2.00e+00 | 5.01e+04 | 0.00e+00 | 1.00e+00 |   2   |
# |   3   |  63   |   3   | +6.2663e+04 | 2.18e+00 | 3.22e+04 | 0.00e+00 | 1.00e+00 |   4   |
# |   4   |  84   |   5   | +2.6168e+04 | 4.12e+00 | 1.38e+04 | 0.00e+00 | 1.00e+00 |   4   |
# |   5   |  105  |   8   | +1.2561e+04 | 4.12e+00 | 7.00e+03 | 0.00e+00 | 1.00e+00 |   4   |
# |   6   |  126  |  11   | +5.4727e+03 | 4.12e+00 | 3.36e+03 | 0.00e+00 | 1.00e+00 |   4   |
# |   7   |  147  |  14   | +2.3805e+03 | 4.12e+00 | 1.69e+03 | 0.00e+00 | 1.00e+00 |   4   |
# |   8   |  168  |  17   | +1.0338e+03 | 4.12e+00 | 8.67e+02 | 0.00e+00 | 1.00e+00 |   4   |
# ...

# %%
antenna.get_optimal_current_allocation(opt_params, x0=probe, cons=False)
# Out:
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  | penalty  |CG stop|
# |-------|-------|-------|-------------|----------|----------|----------|----------|-------|
# |   1   |   1   |   0   | +4.0848e+05 | 1.00e+00 | 2.48e+05 | 0.00e+00 | 1.00e+00 |   0   |
# |   2   |   2   |   6   | +1.4522e+05 | 5.32e+00 | 9.08e+04 | 0.00e+00 | 1.00e+00 |   4   |
# |   3   |   3   |  12   | +5.0577e+04 | 5.32e+00 | 3.31e+04 | 0.00e+00 | 1.00e+00 |   4   |
# |   4   |   4   |  17   | +1.7083e+04 | 5.32e+00 | 1.20e+04 | 0.00e+00 | 1.00e+00 |   4   |
# |   5   |   5   |  23   | +5.5287e+03 | 5.32e+00 | 4.28e+03 | 0.00e+00 | 1.00e+00 |   4   |
# |   6   |   6   |  29   | +1.6964e+03 | 5.32e+00 | 1.50e+03 | 0.00e+00 | 1.00e+00 |   4   |
# |   7   |   7   |  35   | +5.0334e+02 | 5.32e+00 | 5.06e+02 | 0.00e+00 | 1.00e+00 |   4   |
# |   8   |   8   |  40   | +1.7582e+02 | 5.32e+00 | 1.58e+02 | 0.00e+00 | 1.00e+00 |   4   |
# ...

# %%
antenna2 = Antenna(antenna_params)
antenna2.set_objective(weights=[1.0, 1.0])
antenna2.set_jacobian(weights=[1.0, 1.0])
antenna2.set_hessian(weights=[1.0, 1.0])

# %%
probe = np.array([-10, -10, 1, 1])
print(f"Probe signal: \n{probe}\n")
print(f"Objective_f: \n{antenna2.objective(probe)}\n")
print(f"Objective_grad_f: \n{antenna2.jac(probe)}\n")
print(f"Objective_hess_f: \n{antenna2.hess(probe)}\n")
